# %% [markdown]
# # Example Sample Hotel and Flight Booker Agent
#
# This solution will help you book flight tickets and hotel.  The scenario is a trip London Heathrow LHR Feb 20th 2024 to New York JFK returning Feb 27th 2025 flying economy with British Airways only. I want a stay in a Hilton hotel in New York please provide costs for the flight and hotel'

# %% [markdown]
# # Initialize the Azure AI Agent Service and get configuration information from **.env**
#
# ### **.env**
#
# Create a .env file
#
# **.env** contains the connection string of Azure AI Agent Service, the model used by AOAI, and the corresponding Google API Search service API, ENDPOINT, etc.
#
# - **AZURE_AI_AGENT_MODEL_DEPLOYMENT_NAME** = "Your Azure AI Agent Service Model Deployment Name"
#
# [**NOTE**] You will need a model with 100,000 Rate Limit (Tokens per minute)  Rate Limit of 600 (Request per minute)
#
#   You can get model in Azure AI Foundry - Model and Endpoint.
#
#
# - **AZURE_AI_AGENT_PROJECT_CONNECTION_STRING** = "Your Azure AI Agent Service Project Connection String"
#
#   You can get the project connection string in your project overview in  AI ​​Foundry Portal Screen.
#
# - **SERPAPI_SEARCH_API_KEY** = "Your SERPAPI Search API KEY"
# - **SERPAPI_SEARCH_ENDPOINT** = "Your SERPAPI Search Endpoint"
#
# To get the Model Deployment Name and Project Connection String of Azure AI Agent Service, you need to create Azure AI Agent Service. It is recommended to use [this template](https://portal.azure.com/#create/Microsoft.Template/uri/https%3A%2F%2Fraw.githubusercontent.com%2Ffosteramanda%2Fazure-agent-quickstart-templates%2Frefs%2Fheads%2Fmaster%2Fquickstarts%2Fmicrosoft.azure-ai-agent-service%2Fstandard-agent%2Fazuredeploy.json) to create it directly （***Note:*** Azure AI Agent Service is currently set in a limited region. It is recommended that you refer to [this link](https://learn.microsoft.com/en-us/azure/ai-services/agents/concepts/model-region-support) to set the region)
#
# Agent needs to access SERPAPI. It is recommended to register using [this link](https://serpapi.com/searches). After registration, you can obtain a unique API KEY and ENDPOINT

# %% [markdown]
# # Setup
#
# To run this notebook, you will need to install the following libraries. Here is a list of the required libraries and the corresponding pip install commands:
#
# azure-identity: For Azure authentication.
# requests: For making HTTP requests.
# semantic-kernel: For the semantic kernel framework (assuming this is a custom or specific library, you might need to install it from a specific source or repository).

# %%
# %pip install azure-identity
# %pip install requests
# %pip install semantic-kernel
# %pip install --upgrade semantic_kernel
# %pip install azure-cli
# Out:
# 8550.39s - pydevd: Sending message related to process being replaced timed-out after 5 seconds
# Requirement already satisfied: azure-identity in /usr/local/python/3.12.1/lib/python3.12/site-packages (1.20.0)
# Requirement already satisfied: azure-core>=1.31.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from azure-identity) (1.32.0)
# Requirement already satisfied: cryptography>=2.5 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from azure-identity) (44.0.2)
# Requirement already satisfied: msal>=1.30.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from azure-identity) (1.31.2b1)
# Requirement already satisfied: msal-extensions>=1.2.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from azure-identity) (1.2.0)
# Requirement already satisfied: typing-extensions>=4.0.0 in /home/codespace/.local/lib/python3.12/site-packages (from azure-identity) (4.12.2)
# Requirement already satisfied: requests>=2.21.0 in /home/codespace/.local/lib/python3.12/site-packages (from azure-core>=1.31.0->azure-identity) (2.32.3)
# Requirement already satisfied: six>=1.11.0 in /home/codespace/.local/lib/python3.12/site-packages (from azure-core>=1.31.0->azure-identity) (1.17.0)
# Requirement already satisfied: cffi>=1.12 in /home/codespace/.local/lib/python3.12/site-packages (from cryptography>=2.5->azure-identity) (1.17.1)
# Requirement already satisfied: PyJWT<3,>=1.0.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from PyJWT[crypto]<3,>=1.0.0->msal>=1.30.0->azure-identity) (2.10.1)
# Requirement already satisfied: portalocker<3,>=1.4 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from msal-extensions>=1.2.0->azure-identity) (2.10.1)
# Requirement already satisfied: pycparser in /home/codespace/.local/lib/python3.12/site-packages (from cffi>=1.12->cryptography>=2.5->azure-identity) (2.22)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/codespace/.local/lib/python3.12/site-packages (from requests>=2.21.0->azure-core>=1.31.0->azure-identity) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /home/codespace/.local/lib/python3.12/site-packages (from requests>=2.21.0->azure-core>=1.31.0->azure-identity) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/codespace/.local/lib/python3.12/site-packages (from requests>=2.21.0->azure-core>=1.31.0->azure-identity) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /home/codespace/.local/lib/python3.12/site-packages (from requests>=2.21.0->azure-core>=1.31.0->azure-identity) (2024.8.30)
#
# [notice] A new release of pip is available: 24.3.1 -> 25.0.1
# [notice] To update, run: python -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# 8556.70s - pydevd: Sending message related to process being replaced timed-out after 5 seconds
# Requirement already satisfied: requests in /home/codespace/.local/lib/python3.12/site-packages (2.32.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/codespace/.local/lib/python3.12/site-packages (from requests) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /home/codespace/.local/lib/python3.12/site-packages (from requests) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/codespace/.local/lib/python3.12/site-packages (from requests) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /home/codespace/.local/lib/python3.12/site-packages (from requests) (2024.8.30)
#
# [notice] A new release of pip is available: 24.3.1 -> 25.0.1
# [notice] To update, run: python -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# 8562.96s - pydevd: Sending message related to process being replaced timed-out after 5 seconds
# Requirement already satisfied: semantic-kernel in /usr/local/python/3.12.1/lib/python3.12/site-packages (1.24.1)
# Requirement already satisfied: aiohttp~=3.8 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from semantic-kernel) (3.11.13)
# Requirement already satisfied: cloudevents~=1.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from semantic-kernel) (1.11.0)
# Requirement already satisfied: pydantic!=2.10.0,!=2.10.1,!=2.10.2,!=2.10.3,<2.11,>=2.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from semantic-kernel) (2.10.6)
# Requirement already satisfied: pydantic-settings~=2.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from semantic-kernel) (2.8.1)
# Requirement already satisfied: defusedxml~=0.7 in /home/codespace/.local/lib/python3.12/site-packages (from semantic-kernel) (0.7.1)
# Requirement already satisfied: azure-identity~=1.13 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from semantic-kernel) (1.20.0)
# Requirement already satisfied: numpy>=1.26.0 in /home/codespace/.local/lib/python3.12/site-packages (from semantic-kernel) (2.2.0)
# Requirement already satisfied: openai~=1.61 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from semantic-kernel) (1.65.2)
# Requirement already satisfied: openapi_core<0.20,>=0.18 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from semantic-kernel) (0.19.4)
# Requirement already satisfied: websockets<16,>=13 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from semantic-kernel) (14.2)
# Requirement already satisfied: aiortc>=1.9.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from semantic-kernel) (1.10.1)
# Requirement already satisfied: opentelemetry-api~=1.24 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from semantic-kernel) (1.30.0)
# Requirement already satisfied: opentelemetry-sdk~=1.24 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from semantic-kernel) (1.30.0)
# Requirement already satisfied: prance~=23.6.21.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from semantic-kernel) (23.6.21.0)
# Requirement already satisfied: pybars4~=0.9 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from semantic-kernel) (0.9.13)
# Requirement already satisfied: jinja2~=3.1 in /home/codespace/.local/lib/python3.12/site-packages (from semantic-kernel) (3.1.4)
# Requirement already satisfied: nest-asyncio~=1.6 in /home/codespace/.local/lib/python3.12/site-packages (from semantic-kernel) (1.6.0)
# Requirement already satisfied: scipy>=1.15.1 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from semantic-kernel) (1.15.2)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from aiohttp~=3.8->semantic-kernel) (2.4.6)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from aiohttp~=3.8->semantic-kernel) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /home/codespace/.local/lib/python3.12/site-packages (from aiohttp~=3.8->semantic-kernel) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from aiohttp~=3.8->semantic-kernel) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from aiohttp~=3.8->semantic-kernel) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from aiohttp~=3.8->semantic-kernel) (0.3.0)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from aiohttp~=3.8->semantic-kernel) (1.18.3)
# Requirement already satisfied: aioice<1.0.0,>=0.9.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from aiortc>=1.9.0->semantic-kernel) (0.9.0)
# Requirement already satisfied: av<14.0.0,>=9.0.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from aiortc>=1.9.0->semantic-kernel) (13.1.0)
# Requirement already satisfied: cffi>=1.0.0 in /home/codespace/.local/lib/python3.12/site-packages (from aiortc>=1.9.0->semantic-kernel) (1.17.1)
# Requirement already satisfied: cryptography>=42.0.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from aiortc>=1.9.0->semantic-kernel) (44.0.2)
# Requirement already satisfied: google-crc32c>=1.1 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from aiortc>=1.9.0->semantic-kernel) (1.6.0)
# Requirement already satisfied: pyee>=9.0.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from aiortc>=1.9.0->semantic-kernel) (12.1.1)
# Requirement already satisfied: pylibsrtp>=0.10.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from aiortc>=1.9.0->semantic-kernel) (0.11.0)
# Requirement already satisfied: pyopenssl>=24.0.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from aiortc>=1.9.0->semantic-kernel) (25.0.0)
# Requirement already satisfied: azure-core>=1.31.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from azure-identity~=1.13->semantic-kernel) (1.32.0)
# Requirement already satisfied: msal>=1.30.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from azure-identity~=1.13->semantic-kernel) (1.31.2b1)
# Requirement already satisfied: msal-extensions>=1.2.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from azure-identity~=1.13->semantic-kernel) (1.2.0)
# Requirement already satisfied: typing-extensions>=4.0.0 in /home/codespace/.local/lib/python3.12/site-packages (from azure-identity~=1.13->semantic-kernel) (4.12.2)
# Requirement already satisfied: deprecation<3.0,>=2.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from cloudevents~=1.0->semantic-kernel) (2.1.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/codespace/.local/lib/python3.12/site-packages (from jinja2~=3.1->semantic-kernel) (3.0.2)
# Requirement already satisfied: anyio<5,>=3.5.0 in /home/codespace/.local/lib/python3.12/site-packages (from openai~=1.61->semantic-kernel) (4.7.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from openai~=1.61->semantic-kernel) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /home/codespace/.local/lib/python3.12/site-packages (from openai~=1.61->semantic-kernel) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.4.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from openai~=1.61->semantic-kernel) (0.8.2)
# Requirement already satisfied: sniffio in /home/codespace/.local/lib/python3.12/site-packages (from openai~=1.61->semantic-kernel) (1.3.1)
# Requirement already satisfied: tqdm>4 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from openai~=1.61->semantic-kernel) (4.67.1)
# Requirement already satisfied: isodate in /usr/local/python/3.12.1/lib/python3.12/site-packages (from openapi_core<0.20,>=0.18->semantic-kernel) (0.7.2)
# Requirement already satisfied: jsonschema<5.0.0,>=4.18.0 in /home/codespace/.local/lib/python3.12/site-packages (from openapi_core<0.20,>=0.18->semantic-kernel) (4.23.0)
# Requirement already satisfied: jsonschema-path<0.4.0,>=0.3.1 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from openapi_core<0.20,>=0.18->semantic-kernel) (0.3.4)
# Requirement already satisfied: more-itertools in /usr/local/python/3.12.1/lib/python3.12/site-packages (from openapi_core<0.20,>=0.18->semantic-kernel) (10.6.0)
# Requirement already satisfied: openapi-schema-validator<0.7.0,>=0.6.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from openapi_core<0.20,>=0.18->semantic-kernel) (0.6.3)
# Requirement already satisfied: openapi-spec-validator<0.8.0,>=0.7.1 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from openapi_core<0.20,>=0.18->semantic-kernel) (0.7.1)
# Requirement already satisfied: parse in /usr/local/python/3.12.1/lib/python3.12/site-packages (from openapi_core<0.20,>=0.18->semantic-kernel) (1.20.2)
# Requirement already satisfied: werkzeug in /usr/local/python/3.12.1/lib/python3.12/site-packages (from openapi_core<0.20,>=0.18->semantic-kernel) (3.1.3)
# Requirement already satisfied: deprecated>=1.2.6 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from opentelemetry-api~=1.24->semantic-kernel) (1.2.18)
# Requirement already satisfied: importlib-metadata<=8.5.0,>=6.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from opentelemetry-api~=1.24->semantic-kernel) (8.5.0)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.51b0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from opentelemetry-sdk~=1.24->semantic-kernel) (0.51b0)
# Requirement already satisfied: chardet>=3.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from prance~=23.6.21.0->semantic-kernel) (5.2.0)
# Requirement already satisfied: ruamel.yaml>=0.17.10 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from prance~=23.6.21.0->semantic-kernel) (0.18.10)
# Requirement already satisfied: requests>=2.25 in /home/codespace/.local/lib/python3.12/site-packages (from prance~=23.6.21.0->semantic-kernel) (2.32.3)
# Requirement already satisfied: six~=1.15 in /home/codespace/.local/lib/python3.12/site-packages (from prance~=23.6.21.0->semantic-kernel) (1.17.0)
# Requirement already satisfied: packaging>=21.3 in /home/codespace/.local/lib/python3.12/site-packages (from prance~=23.6.21.0->semantic-kernel) (24.2)
# Requirement already satisfied: PyMeta3>=0.5.1 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from pybars4~=0.9->semantic-kernel) (0.5.1)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from pydantic!=2.10.0,!=2.10.1,!=2.10.2,!=2.10.3,<2.11,>=2.0->semantic-kernel) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from pydantic!=2.10.0,!=2.10.1,!=2.10.2,!=2.10.3,<2.11,>=2.0->semantic-kernel) (2.27.2)
# Requirement already satisfied: python-dotenv>=0.21.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from pydantic-settings~=2.0->semantic-kernel) (1.0.1)
# Requirement already satisfied: dnspython>=2.0.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from aioice<1.0.0,>=0.9.0->aiortc>=1.9.0->semantic-kernel) (2.7.0)
# Requirement already satisfied: ifaddr>=0.2.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from aioice<1.0.0,>=0.9.0->aiortc>=1.9.0->semantic-kernel) (0.2.0)
# Requirement already satisfied: idna>=2.8 in /home/codespace/.local/lib/python3.12/site-packages (from anyio<5,>=3.5.0->openai~=1.61->semantic-kernel) (3.10)
# Requirement already satisfied: pycparser in /home/codespace/.local/lib/python3.12/site-packages (from cffi>=1.0.0->aiortc>=1.9.0->semantic-kernel) (2.22)
# Requirement already satisfied: wrapt<2,>=1.10 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from deprecated>=1.2.6->opentelemetry-api~=1.24->semantic-kernel) (1.17.2)
# Requirement already satisfied: certifi in /home/codespace/.local/lib/python3.12/site-packages (from httpx<1,>=0.23.0->openai~=1.61->semantic-kernel) (2024.8.30)
# Requirement already satisfied: httpcore==1.* in /home/codespace/.local/lib/python3.12/site-packages (from httpx<1,>=0.23.0->openai~=1.61->semantic-kernel) (1.0.7)
# Requirement already satisfied: h11<0.15,>=0.13 in /home/codespace/.local/lib/python3.12/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai~=1.61->semantic-kernel) (0.14.0)
# Requirement already satisfied: zipp>=3.20 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from importlib-metadata<=8.5.0,>=6.0->opentelemetry-api~=1.24->semantic-kernel) (3.21.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /home/codespace/.local/lib/python3.12/site-packages (from jsonschema<5.0.0,>=4.18.0->openapi_core<0.20,>=0.18->semantic-kernel) (2024.10.1)
# Requirement already satisfied: referencing>=0.28.4 in /home/codespace/.local/lib/python3.12/site-packages (from jsonschema<5.0.0,>=4.18.0->openapi_core<0.20,>=0.18->semantic-kernel) (0.35.1)
# Requirement already satisfied: rpds-py>=0.7.1 in /home/codespace/.local/lib/python3.12/site-packages (from jsonschema<5.0.0,>=4.18.0->openapi_core<0.20,>=0.18->semantic-kernel) (0.22.3)
# Requirement already satisfied: PyYAML>=5.1 in /home/codespace/.local/lib/python3.12/site-packages (from jsonschema-path<0.4.0,>=0.3.1->openapi_core<0.20,>=0.18->semantic-kernel) (6.0.2)
# Requirement already satisfied: pathable<0.5.0,>=0.4.1 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from jsonschema-path<0.4.0,>=0.3.1->openapi_core<0.20,>=0.18->semantic-kernel) (0.4.4)
# Requirement already satisfied: PyJWT<3,>=1.0.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from PyJWT[crypto]<3,>=1.0.0->msal>=1.30.0->azure-identity~=1.13->semantic-kernel) (2.10.1)
# Requirement already satisfied: portalocker<3,>=1.4 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from msal-extensions>=1.2.0->azure-identity~=1.13->semantic-kernel) (2.10.1)
# Requirement already satisfied: rfc3339-validator in /home/codespace/.local/lib/python3.12/site-packages (from openapi-schema-validator<0.7.0,>=0.6.0->openapi_core<0.20,>=0.18->semantic-kernel) (0.1.4)
# Requirement already satisfied: lazy-object-proxy<2.0.0,>=1.7.1 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from openapi-spec-validator<0.8.0,>=0.7.1->openapi_core<0.20,>=0.18->semantic-kernel) (1.10.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/codespace/.local/lib/python3.12/site-packages (from requests>=2.25->prance~=23.6.21.0->semantic-kernel) (3.4.0)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/codespace/.local/lib/python3.12/site-packages (from requests>=2.25->prance~=23.6.21.0->semantic-kernel) (2.2.3)
# Requirement already satisfied: ruamel.yaml.clib>=0.2.7 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from ruamel.yaml>=0.17.10->prance~=23.6.21.0->semantic-kernel) (0.2.12)
#
# [notice] A new release of pip is available: 24.3.1 -> 25.0.1
# [notice] To update, run: python -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# 8569.38s - pydevd: Sending message related to process being replaced timed-out after 5 seconds
# Requirement already satisfied: semantic_kernel in /usr/local/python/3.12.1/lib/python3.12/site-packages (1.24.1)
# Requirement already satisfied: aiohttp~=3.8 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from semantic_kernel) (3.11.13)
# Requirement already satisfied: cloudevents~=1.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from semantic_kernel) (1.11.0)
# Requirement already satisfied: pydantic!=2.10.0,!=2.10.1,!=2.10.2,!=2.10.3,<2.11,>=2.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from semantic_kernel) (2.10.6)
# Requirement already satisfied: pydantic-settings~=2.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from semantic_kernel) (2.8.1)
# Requirement already satisfied: defusedxml~=0.7 in /home/codespace/.local/lib/python3.12/site-packages (from semantic_kernel) (0.7.1)
# Requirement already satisfied: azure-identity~=1.13 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from semantic_kernel) (1.20.0)
# Requirement already satisfied: numpy>=1.26.0 in /home/codespace/.local/lib/python3.12/site-packages (from semantic_kernel) (2.2.0)
# Requirement already satisfied: openai~=1.61 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from semantic_kernel) (1.65.2)
# Requirement already satisfied: openapi_core<0.20,>=0.18 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from semantic_kernel) (0.19.4)
# Requirement already satisfied: websockets<16,>=13 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from semantic_kernel) (14.2)
# Requirement already satisfied: aiortc>=1.9.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from semantic_kernel) (1.10.1)
# Requirement already satisfied: opentelemetry-api~=1.24 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from semantic_kernel) (1.30.0)
# Requirement already satisfied: opentelemetry-sdk~=1.24 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from semantic_kernel) (1.30.0)
# Requirement already satisfied: prance~=23.6.21.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from semantic_kernel) (23.6.21.0)
# Requirement already satisfied: pybars4~=0.9 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from semantic_kernel) (0.9.13)
# Requirement already satisfied: jinja2~=3.1 in /home/codespace/.local/lib/python3.12/site-packages (from semantic_kernel) (3.1.4)
# Requirement already satisfied: nest-asyncio~=1.6 in /home/codespace/.local/lib/python3.12/site-packages (from semantic_kernel) (1.6.0)
# Requirement already satisfied: scipy>=1.15.1 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from semantic_kernel) (1.15.2)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from aiohttp~=3.8->semantic_kernel) (2.4.6)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from aiohttp~=3.8->semantic_kernel) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /home/codespace/.local/lib/python3.12/site-packages (from aiohttp~=3.8->semantic_kernel) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from aiohttp~=3.8->semantic_kernel) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from aiohttp~=3.8->semantic_kernel) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from aiohttp~=3.8->semantic_kernel) (0.3.0)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from aiohttp~=3.8->semantic_kernel) (1.18.3)
# Requirement already satisfied: aioice<1.0.0,>=0.9.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from aiortc>=1.9.0->semantic_kernel) (0.9.0)
# Requirement already satisfied: av<14.0.0,>=9.0.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from aiortc>=1.9.0->semantic_kernel) (13.1.0)
# Requirement already satisfied: cffi>=1.0.0 in /home/codespace/.local/lib/python3.12/site-packages (from aiortc>=1.9.0->semantic_kernel) (1.17.1)
# Requirement already satisfied: cryptography>=42.0.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from aiortc>=1.9.0->semantic_kernel) (44.0.2)
# Requirement already satisfied: google-crc32c>=1.1 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from aiortc>=1.9.0->semantic_kernel) (1.6.0)
# Requirement already satisfied: pyee>=9.0.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from aiortc>=1.9.0->semantic_kernel) (12.1.1)
# Requirement already satisfied: pylibsrtp>=0.10.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from aiortc>=1.9.0->semantic_kernel) (0.11.0)
# Requirement already satisfied: pyopenssl>=24.0.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from aiortc>=1.9.0->semantic_kernel) (25.0.0)
# Requirement already satisfied: azure-core>=1.31.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from azure-identity~=1.13->semantic_kernel) (1.32.0)
# Requirement already satisfied: msal>=1.30.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from azure-identity~=1.13->semantic_kernel) (1.31.2b1)
# Requirement already satisfied: msal-extensions>=1.2.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from azure-identity~=1.13->semantic_kernel) (1.2.0)
# Requirement already satisfied: typing-extensions>=4.0.0 in /home/codespace/.local/lib/python3.12/site-packages (from azure-identity~=1.13->semantic_kernel) (4.12.2)
# Requirement already satisfied: deprecation<3.0,>=2.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from cloudevents~=1.0->semantic_kernel) (2.1.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/codespace/.local/lib/python3.12/site-packages (from jinja2~=3.1->semantic_kernel) (3.0.2)
# Requirement already satisfied: anyio<5,>=3.5.0 in /home/codespace/.local/lib/python3.12/site-packages (from openai~=1.61->semantic_kernel) (4.7.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from openai~=1.61->semantic_kernel) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /home/codespace/.local/lib/python3.12/site-packages (from openai~=1.61->semantic_kernel) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.4.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from openai~=1.61->semantic_kernel) (0.8.2)
# Requirement already satisfied: sniffio in /home/codespace/.local/lib/python3.12/site-packages (from openai~=1.61->semantic_kernel) (1.3.1)
# Requirement already satisfied: tqdm>4 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from openai~=1.61->semantic_kernel) (4.67.1)
# Requirement already satisfied: isodate in /usr/local/python/3.12.1/lib/python3.12/site-packages (from openapi_core<0.20,>=0.18->semantic_kernel) (0.7.2)
# Requirement already satisfied: jsonschema<5.0.0,>=4.18.0 in /home/codespace/.local/lib/python3.12/site-packages (from openapi_core<0.20,>=0.18->semantic_kernel) (4.23.0)
# Requirement already satisfied: jsonschema-path<0.4.0,>=0.3.1 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from openapi_core<0.20,>=0.18->semantic_kernel) (0.3.4)
# Requirement already satisfied: more-itertools in /usr/local/python/3.12.1/lib/python3.12/site-packages (from openapi_core<0.20,>=0.18->semantic_kernel) (10.6.0)
# Requirement already satisfied: openapi-schema-validator<0.7.0,>=0.6.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from openapi_core<0.20,>=0.18->semantic_kernel) (0.6.3)
# Requirement already satisfied: openapi-spec-validator<0.8.0,>=0.7.1 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from openapi_core<0.20,>=0.18->semantic_kernel) (0.7.1)
# Requirement already satisfied: parse in /usr/local/python/3.12.1/lib/python3.12/site-packages (from openapi_core<0.20,>=0.18->semantic_kernel) (1.20.2)
# Requirement already satisfied: werkzeug in /usr/local/python/3.12.1/lib/python3.12/site-packages (from openapi_core<0.20,>=0.18->semantic_kernel) (3.1.3)
# Requirement already satisfied: deprecated>=1.2.6 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from opentelemetry-api~=1.24->semantic_kernel) (1.2.18)
# Requirement already satisfied: importlib-metadata<=8.5.0,>=6.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from opentelemetry-api~=1.24->semantic_kernel) (8.5.0)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.51b0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from opentelemetry-sdk~=1.24->semantic_kernel) (0.51b0)
# Requirement already satisfied: chardet>=3.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from prance~=23.6.21.0->semantic_kernel) (5.2.0)
# Requirement already satisfied: ruamel.yaml>=0.17.10 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from prance~=23.6.21.0->semantic_kernel) (0.18.10)
# Requirement already satisfied: requests>=2.25 in /home/codespace/.local/lib/python3.12/site-packages (from prance~=23.6.21.0->semantic_kernel) (2.32.3)
# Requirement already satisfied: six~=1.15 in /home/codespace/.local/lib/python3.12/site-packages (from prance~=23.6.21.0->semantic_kernel) (1.17.0)
# Requirement already satisfied: packaging>=21.3 in /home/codespace/.local/lib/python3.12/site-packages (from prance~=23.6.21.0->semantic_kernel) (24.2)
# Requirement already satisfied: PyMeta3>=0.5.1 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from pybars4~=0.9->semantic_kernel) (0.5.1)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from pydantic!=2.10.0,!=2.10.1,!=2.10.2,!=2.10.3,<2.11,>=2.0->semantic_kernel) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from pydantic!=2.10.0,!=2.10.1,!=2.10.2,!=2.10.3,<2.11,>=2.0->semantic_kernel) (2.27.2)
# Requirement already satisfied: python-dotenv>=0.21.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from pydantic-settings~=2.0->semantic_kernel) (1.0.1)
# Requirement already satisfied: dnspython>=2.0.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from aioice<1.0.0,>=0.9.0->aiortc>=1.9.0->semantic_kernel) (2.7.0)
# Requirement already satisfied: ifaddr>=0.2.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from aioice<1.0.0,>=0.9.0->aiortc>=1.9.0->semantic_kernel) (0.2.0)
# Requirement already satisfied: idna>=2.8 in /home/codespace/.local/lib/python3.12/site-packages (from anyio<5,>=3.5.0->openai~=1.61->semantic_kernel) (3.10)
# Requirement already satisfied: pycparser in /home/codespace/.local/lib/python3.12/site-packages (from cffi>=1.0.0->aiortc>=1.9.0->semantic_kernel) (2.22)
# Requirement already satisfied: wrapt<2,>=1.10 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from deprecated>=1.2.6->opentelemetry-api~=1.24->semantic_kernel) (1.17.2)
# Requirement already satisfied: certifi in /home/codespace/.local/lib/python3.12/site-packages (from httpx<1,>=0.23.0->openai~=1.61->semantic_kernel) (2024.8.30)
# Requirement already satisfied: httpcore==1.* in /home/codespace/.local/lib/python3.12/site-packages (from httpx<1,>=0.23.0->openai~=1.61->semantic_kernel) (1.0.7)
# Requirement already satisfied: h11<0.15,>=0.13 in /home/codespace/.local/lib/python3.12/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai~=1.61->semantic_kernel) (0.14.0)
# Requirement already satisfied: zipp>=3.20 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from importlib-metadata<=8.5.0,>=6.0->opentelemetry-api~=1.24->semantic_kernel) (3.21.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /home/codespace/.local/lib/python3.12/site-packages (from jsonschema<5.0.0,>=4.18.0->openapi_core<0.20,>=0.18->semantic_kernel) (2024.10.1)
# Requirement already satisfied: referencing>=0.28.4 in /home/codespace/.local/lib/python3.12/site-packages (from jsonschema<5.0.0,>=4.18.0->openapi_core<0.20,>=0.18->semantic_kernel) (0.35.1)
# Requirement already satisfied: rpds-py>=0.7.1 in /home/codespace/.local/lib/python3.12/site-packages (from jsonschema<5.0.0,>=4.18.0->openapi_core<0.20,>=0.18->semantic_kernel) (0.22.3)
# Requirement already satisfied: PyYAML>=5.1 in /home/codespace/.local/lib/python3.12/site-packages (from jsonschema-path<0.4.0,>=0.3.1->openapi_core<0.20,>=0.18->semantic_kernel) (6.0.2)
# Requirement already satisfied: pathable<0.5.0,>=0.4.1 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from jsonschema-path<0.4.0,>=0.3.1->openapi_core<0.20,>=0.18->semantic_kernel) (0.4.4)
# Requirement already satisfied: PyJWT<3,>=1.0.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from PyJWT[crypto]<3,>=1.0.0->msal>=1.30.0->azure-identity~=1.13->semantic_kernel) (2.10.1)
# Requirement already satisfied: portalocker<3,>=1.4 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from msal-extensions>=1.2.0->azure-identity~=1.13->semantic_kernel) (2.10.1)
# Requirement already satisfied: rfc3339-validator in /home/codespace/.local/lib/python3.12/site-packages (from openapi-schema-validator<0.7.0,>=0.6.0->openapi_core<0.20,>=0.18->semantic_kernel) (0.1.4)
# Requirement already satisfied: lazy-object-proxy<2.0.0,>=1.7.1 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from openapi-spec-validator<0.8.0,>=0.7.1->openapi_core<0.20,>=0.18->semantic_kernel) (1.10.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/codespace/.local/lib/python3.12/site-packages (from requests>=2.25->prance~=23.6.21.0->semantic_kernel) (3.4.0)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/codespace/.local/lib/python3.12/site-packages (from requests>=2.25->prance~=23.6.21.0->semantic_kernel) (2.2.3)
# Requirement already satisfied: ruamel.yaml.clib>=0.2.7 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from ruamel.yaml>=0.17.10->prance~=23.6.21.0->semantic_kernel) (0.2.12)
#
# [notice] A new release of pip is available: 24.3.1 -> 25.0.1
# [notice] To update, run: python -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# 8575.88s - pydevd: Sending message related to process being replaced timed-out after 5 seconds
# Requirement already satisfied: azure-cli in /usr/local/python/3.12.1/lib/python3.12/site-packages (2.70.0)
# Requirement already satisfied: antlr4-python3-runtime~=4.13.1 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from azure-cli) (4.13.2)
# Requirement already satisfied: azure-appconfiguration~=1.7.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from azure-cli) (1.7.1)
# Requirement already satisfied: azure-batch~=15.0.0b1 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from azure-cli) (15.0.0b1)
# Requirement already satisfied: azure-cli-core==2.70.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from azure-cli) (2.70.0)
# Requirement already satisfied: azure-cosmos>=3.0.2,~=3.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from azure-cli) (3.2.0)
# Requirement already satisfied: azure-data-tables==12.4.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from azure-cli) (12.4.0)
# Requirement already satisfied: azure-datalake-store~=1.0.0a0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from azure-cli) (1.0.0a0)
# Requirement already satisfied: azure-keyvault-administration==4.4.0b2 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from azure-cli) (4.4.0b2)
# Requirement already satisfied: azure-keyvault-certificates==4.7.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from azure-cli) (4.7.0)
# Requirement already satisfied: azure-keyvault-keys==4.9.0b3 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from azure-cli) (4.9.0b3)
# Requirement already satisfied: azure-keyvault-secrets==4.7.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from azure-cli) (4.7.0)
# Requirement already satisfied: azure-mgmt-advisor==9.0.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from azure-cli) (9.0.0)
# Requirement already satisfied: azure-mgmt-apimanagement==4.0.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from azure-cli) (4.0.0)
# Requirement already satisfied: azure-mgmt-appconfiguration==3.1.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from azure-cli) (3.1.0)
# Requirement already satisfied: azure-mgmt-appcontainers==2.0.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from azure-cli) (2.0.0)
# Requirement already satisfied: azure-mgmt-applicationinsights~=1.0.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from azure-cli) (1.0.0)
# Requirement already satisfied: azure-mgmt-authorization~=4.0.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from azure-cli) (4.0.0)
# Requirement already satisfied: azure-mgmt-batchai==7.0.0b1 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from azure-cli) (7.0.0b1)
# Requirement already satisfied: azure-mgmt-batch~=17.3.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from azure-cli) (17.3.0)
# Requirement already satisfied: azure-mgmt-billing==6.0.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from azure-cli) (6.0.0)
# Requirement already satisfied: azure-mgmt-botservice~=2.0.0b3 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from azure-cli) (2.0.0)
# Requirement already satisfied: azure-mgmt-cdn==12.0.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from azure-cli) (12.0.0)
# Requirement already satisfied: azure-mgmt-cognitiveservices~=13.5.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from azure-cli) (13.5.0)
# Requirement already satisfied: azure-mgmt-compute~=33.0.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from azure-cli) (33.0.0)
# Requirement already satisfied: azure-mgmt-containerinstance==10.2.0b1 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from azure-cli) (10.2.0b1)
# Requirement already satisfied: azure-mgmt-containerregistry==10.3.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from azure-cli) (10.3.0)
# Requirement already satisfied: azure-mgmt-containerservice~=34.1.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from azure-cli) (34.1.0)
# Requirement already satisfied: azure-mgmt-cosmosdb==9.7.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from azure-cli) (9.7.0)
# Requirement already satisfied: azure-mgmt-databoxedge~=1.0.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from azure-cli) (1.0.0)
# Requirement already satisfied: azure-mgmt-datalake-store~=1.1.0b1 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from azure-cli) (1.1.0b1)
# Requirement already satisfied: azure-mgmt-datamigration~=10.0.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from azure-cli) (10.0.0)
# Requirement already satisfied: azure-mgmt-dns~=8.0.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from azure-cli) (8.0.0)
# Requirement already satisfied: azure-mgmt-eventgrid==10.2.0b2 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from azure-cli) (10.2.0b2)
# Requirement already satisfied: azure-mgmt-eventhub~=10.1.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from azure-cli) (10.1.0)
# Requirement already satisfied: azure-mgmt-extendedlocation==1.0.0b2 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from azure-cli) (1.0.0b2)
# Requirement already satisfied: azure-mgmt-hdinsight==9.0.0b3 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from azure-cli) (9.0.0b3)
# Requirement already satisfied: azure-mgmt-imagebuilder~=1.3.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from azure-cli) (1.3.0)
# Requirement already satisfied: azure-mgmt-iotcentral~=10.0.0b1 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from azure-cli) (10.0.0b2)
# Requirement already satisfied: azure-mgmt-iothub==3.0.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from azure-cli) (3.0.0)
# Requirement already satisfied: azure-mgmt-iothubprovisioningservices==1.1.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from azure-cli) (1.1.0)
# Requirement already satisfied: azure-mgmt-keyvault==10.3.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from azure-cli) (10.3.0)
# Requirement already satisfied: azure-mgmt-loganalytics==13.0.0b4 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from azure-cli) (13.0.0b4)
# Requirement already satisfied: azure-mgmt-managementgroups~=1.0.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from azure-cli) (1.0.0)
# Requirement already satisfied: azure-mgmt-maps~=2.0.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from azure-cli) (2.0.0)
# Requirement already satisfied: azure-mgmt-marketplaceordering==1.1.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from azure-cli) (1.1.0)
# Requirement already satisfied: azure-mgmt-media~=9.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from azure-cli) (9.0.0)
# Requirement already satisfied: azure-mgmt-monitor~=5.0.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from azure-cli) (5.0.1)
# Requirement already satisfied: azure-mgmt-msi~=7.0.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from azure-cli) (7.0.0)
# Requirement already satisfied: azure-mgmt-netapp~=10.1.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from azure-cli) (10.1.0)
# Requirement already satisfied: azure-mgmt-policyinsights==1.1.0b4 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from azure-cli) (1.1.0b4)
# Requirement already satisfied: azure-mgmt-postgresqlflexibleservers==1.1.0b2 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from azure-cli) (1.1.0b2)
# Requirement already satisfied: azure-mgmt-privatedns~=1.0.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from azure-cli) (1.0.0)
# Requirement already satisfied: azure-mgmt-rdbms==10.2.0b17 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from azure-cli) (10.2.0b17)
# Requirement already satisfied: azure-mgmt-mysqlflexibleservers==1.0.0b3 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from azure-cli) (1.0.0b3)
# Requirement already satisfied: azure-mgmt-recoveryservicesbackup~=9.1.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from azure-cli) (9.1.0)
# Requirement already satisfied: azure-mgmt-recoveryservices~=3.0.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from azure-cli) (3.0.0)
# Requirement already satisfied: azure-mgmt-redhatopenshift~=1.5.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from azure-cli) (1.5.0)
# Requirement already satisfied: azure-mgmt-redis~=14.5.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from azure-cli) (14.5.0)
# Requirement already satisfied: azure-mgmt-resource==23.1.1 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from azure-cli) (23.1.1)
# Requirement already satisfied: azure-mgmt-search~=9.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from azure-cli) (9.1.0)
# Requirement already satisfied: azure-mgmt-security==6.0.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from azure-cli) (6.0.0)
# Requirement already satisfied: azure-mgmt-servicebus~=8.2.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from azure-cli) (8.2.1)
# Requirement already satisfied: azure-mgmt-servicefabricmanagedclusters==2.1.0b1 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from azure-cli) (2.1.0b1)
# Requirement already satisfied: azure-mgmt-servicelinker==1.2.0b3 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from azure-cli) (1.2.0b3)
# Requirement already satisfied: azure-mgmt-servicefabric~=2.1.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from azure-cli) (2.1.0)
# Requirement already satisfied: azure-mgmt-signalr==2.0.0b2 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from azure-cli) (2.0.0b2)
# Requirement already satisfied: azure-mgmt-sqlvirtualmachine==1.0.0b5 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from azure-cli) (1.0.0b5)
# Requirement already satisfied: azure-mgmt-sql==4.0.0b20 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from azure-cli) (4.0.0b20)
# Requirement already satisfied: azure-mgmt-storage==22.1.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from azure-cli) (22.1.0)
# Requirement already satisfied: azure-mgmt-synapse==2.1.0b5 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from azure-cli) (2.1.0b5)
# Requirement already satisfied: azure-mgmt-trafficmanager~=1.0.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from azure-cli) (1.0.0)
# Requirement already satisfied: azure-mgmt-web==7.3.1 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from azure-cli) (7.3.1)
# Requirement already satisfied: azure-monitor-query==1.2.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from azure-cli) (1.2.0)
# Requirement already satisfied: azure-multiapi-storage~=1.3.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from azure-cli) (1.3.0)
# Requirement already satisfied: azure-storage-common~=1.4 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from azure-cli) (1.4.2)
# Requirement already satisfied: azure-synapse-accesscontrol~=0.5.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from azure-cli) (0.5.0)
# Requirement already satisfied: azure-synapse-artifacts~=0.20.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from azure-cli) (0.20.0)
# Requirement already satisfied: azure-synapse-managedprivateendpoints~=0.4.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from azure-cli) (0.4.0)
# Requirement already satisfied: azure-synapse-spark~=0.7.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from azure-cli) (0.7.0)
# Requirement already satisfied: chardet~=5.2.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from azure-cli) (5.2.0)
# Requirement already satisfied: colorama~=0.4.4 in /home/codespace/.local/lib/python3.12/site-packages (from azure-cli) (0.4.6)
# Requirement already satisfied: distro in /usr/local/python/3.12.1/lib/python3.12/site-packages (from azure-cli) (1.9.0)
# Requirement already satisfied: fabric~=3.2.2 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from azure-cli) (3.2.2)
# Requirement already satisfied: javaproperties~=0.5.1 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from azure-cli) (0.5.2)
# Requirement already satisfied: jsondiff~=2.0.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from azure-cli) (2.0.0)
# Requirement already satisfied: packaging>=20.9 in /home/codespace/.local/lib/python3.12/site-packages (from azure-cli) (24.2)
# Requirement already satisfied: paramiko<4.0.0,>=2.0.8 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from azure-cli) (3.5.1)
# Requirement already satisfied: pycomposefile>=0.0.32 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from azure-cli) (0.0.32)
# Requirement already satisfied: PyGithub~=1.38 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from azure-cli) (1.59.1)
# Requirement already satisfied: PyNaCl~=1.5.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from azure-cli) (1.5.0)
# Requirement already satisfied: scp~=0.13.2 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from azure-cli) (0.13.6)
# Requirement already satisfied: semver==2.13.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from azure-cli) (2.13.0)
# Requirement already satisfied: setuptools in /home/codespace/.local/lib/python3.12/site-packages (from azure-cli) (75.6.0)
# Requirement already satisfied: six>=1.10.0 in /home/codespace/.local/lib/python3.12/site-packages (from azure-cli) (1.17.0)
# Requirement already satisfied: sshtunnel~=0.1.4 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from azure-cli) (0.1.5)
# Requirement already satisfied: tabulate in /usr/local/python/3.12.1/lib/python3.12/site-packages (from azure-cli) (0.9.0)
# Requirement already satisfied: urllib3 in /home/codespace/.local/lib/python3.12/site-packages (from azure-cli) (2.2.3)
# Requirement already satisfied: websocket-client~=1.3.1 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from azure-cli) (1.3.3)
# Requirement already satisfied: xmltodict~=0.12 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from azure-cli) (0.14.2)
# Requirement already satisfied: argcomplete~=3.5.2 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from azure-cli-core==2.70.0->azure-cli) (3.5.3)
# Requirement already satisfied: azure-cli-telemetry==1.1.0.* in /usr/local/python/3.12.1/lib/python3.12/site-packages (from azure-cli-core==2.70.0->azure-cli) (1.1.0)
# Requirement already satisfied: azure-mgmt-core<2,>=1.2.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from azure-cli-core==2.70.0->azure-cli) (1.5.0)
# Requirement already satisfied: cryptography in /usr/local/python/3.12.1/lib/python3.12/site-packages (from azure-cli-core==2.70.0->azure-cli) (44.0.2)
# Requirement already satisfied: humanfriendly~=10.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from azure-cli-core==2.70.0->azure-cli) (10.0)
# Requirement already satisfied: jmespath in /usr/local/python/3.12.1/lib/python3.12/site-packages (from azure-cli-core==2.70.0->azure-cli) (1.0.1)
# Requirement already satisfied: knack~=0.11.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from azure-cli-core==2.70.0->azure-cli) (0.11.0)
# Requirement already satisfied: microsoft-security-utilities-secret-masker~=1.0.0b2 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from azure-cli-core==2.70.0->azure-cli) (1.0.0b3)
# Requirement already satisfied: msal-extensions==1.2.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from azure-cli-core==2.70.0->azure-cli) (1.2.0)
# Requirement already satisfied: msal==1.31.2b1 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from msal[broker]==1.31.2b1->azure-cli-core==2.70.0->azure-cli) (1.31.2b1)
# Requirement already satisfied: msrestazure~=0.6.4 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from azure-cli-core==2.70.0->azure-cli) (0.6.4.post1)
# Requirement already satisfied: pkginfo>=1.5.0.1 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from azure-cli-core==2.70.0->azure-cli) (1.12.1.2)
# Requirement already satisfied: psutil>=5.9 in /home/codespace/.local/lib/python3.12/site-packages (from azure-cli-core==2.70.0->azure-cli) (6.1.0)
# Requirement already satisfied: PyJWT>=2.1.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from azure-cli-core==2.70.0->azure-cli) (2.10.1)
# Requirement already satisfied: pyopenssl>=17.1.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from azure-cli-core==2.70.0->azure-cli) (25.0.0)
# Requirement already satisfied: py-deviceid in /usr/local/python/3.12.1/lib/python3.12/site-packages (from azure-cli-core==2.70.0->azure-cli) (0.1.1)
# Requirement already satisfied: requests[socks] in /home/codespace/.local/lib/python3.12/site-packages (from azure-cli-core==2.70.0->azure-cli) (2.32.3)
# Requirement already satisfied: azure-core<2.0.0,>=1.15.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from azure-data-tables==12.4.0->azure-cli) (1.32.0)
# Requirement already satisfied: msrest>=0.6.21 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from azure-data-tables==12.4.0->azure-cli) (0.7.1)
# Requirement already satisfied: azure-common~=1.1 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from azure-keyvault-administration==4.4.0b2->azure-cli) (1.1.28)
# Requirement already satisfied: isodate>=0.6.1 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from azure-keyvault-administration==4.4.0b2->azure-cli) (0.7.2)
# Requirement already satisfied: typing-extensions>=4.0.1 in /home/codespace/.local/lib/python3.12/site-packages (from azure-keyvault-administration==4.4.0b2->azure-cli) (4.12.2)
# Requirement already satisfied: applicationinsights<0.12,>=0.11.1 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from azure-cli-telemetry==1.1.0.*->azure-cli-core==2.70.0->azure-cli) (0.11.10)
# Requirement already satisfied: portalocker<3,>=1.6 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from azure-cli-telemetry==1.1.0.*->azure-cli-core==2.70.0->azure-cli) (2.10.1)
# Requirement already satisfied: cffi in /home/codespace/.local/lib/python3.12/site-packages (from azure-datalake-store~=1.0.0a0->azure-cli) (1.17.1)
# Requirement already satisfied: python-dateutil in /home/codespace/.local/lib/python3.12/site-packages (from azure-multiapi-storage~=1.3.0->azure-cli) (2.9.0.post0)
# Requirement already satisfied: invoke>=2.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from fabric~=3.2.2->azure-cli) (2.2.0)
# Requirement already satisfied: decorator>=5 in /home/codespace/.local/lib/python3.12/site-packages (from fabric~=3.2.2->azure-cli) (5.1.1)
# Requirement already satisfied: deprecated>=1.2 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from fabric~=3.2.2->azure-cli) (1.2.18)
# Requirement already satisfied: bcrypt>=3.2 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from paramiko<4.0.0,>=2.0.8->azure-cli) (4.3.0)
# Requirement already satisfied: pyyaml in /home/codespace/.local/lib/python3.12/site-packages (from pycomposefile>=0.0.32->azure-cli) (6.0.2)
# Requirement already satisfied: pycparser in /home/codespace/.local/lib/python3.12/site-packages (from cffi->azure-datalake-store~=1.0.0a0->azure-cli) (2.22)
# Requirement already satisfied: wrapt<2,>=1.10 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from deprecated>=1.2->fabric~=3.2.2->azure-cli) (1.17.2)
# Requirement already satisfied: pygments in /home/codespace/.local/lib/python3.12/site-packages (from knack~=0.11.0->azure-cli-core==2.70.0->azure-cli) (2.18.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/codespace/.local/lib/python3.12/site-packages (from msrest>=0.6.21->azure-data-tables==12.4.0->azure-cli) (2024.8.30)
# Requirement already satisfied: requests-oauthlib>=0.5.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from msrest>=0.6.21->azure-data-tables==12.4.0->azure-cli) (2.0.0)
# Requirement already satisfied: adal<2.0.0,>=0.6.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from msrestazure~=0.6.4->azure-cli-core==2.70.0->azure-cli) (1.2.7)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/codespace/.local/lib/python3.12/site-packages (from requests[socks]->azure-cli-core==2.70.0->azure-cli) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /home/codespace/.local/lib/python3.12/site-packages (from requests[socks]->azure-cli-core==2.70.0->azure-cli) (3.10)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from requests[socks]->azure-cli-core==2.70.0->azure-cli) (1.7.1)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from requests-oauthlib>=0.5.0->msrest>=0.6.21->azure-data-tables==12.4.0->azure-cli) (3.2.2)
#
# [notice] A new release of pip is available: 24.3.1 -> 25.0.1
# [notice] To update, run: python -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# # Explanation:
# import asyncio: This imports the asyncio module, which provides support for asynchronous programming in Python. It allows you to write concurrent code using the async and await syntax.
# from typing import Annotated: This imports the Annotated type from the typing module. Annotated is used to add metadata to type hints, which can be useful for various purposes such as validation, documentation, or tooling.

# %%
import asyncio
from typing import Annotated

# %% [markdown]
# # Explanation:
#
# Load your .env file setting and resources please ensure you have added your keys and setting and created a local .env file.

# %%
import os
from dotenv import load_dotenv

# Load environment variables from .env file
load_dotenv()
# Out:
# True

# %% [markdown]
# # Login to Azure
#
# You Now need to login into Azure Open a terminal and run the `az login` command

# %% [markdown]
# # Explanation:
#
# Import Statement: from azure.identity.aio import DefaultAzureCredential: This imports the DefaultAzureCredential class from the azure.identity.aio module. The aio part of the module name indicates that it is designed for asynchronous operations.
#
# Purpose of DefaultAzureCredential: The DefaultAzureCredential class is part of the Azure SDK for Python. It provides a default way to authenticate with Azure services. It attempts to authenticate using multiple methods in a specific order, such as environment variables, managed identity, and Azure CLI credentials.
#
# Asynchronous Operations:The aio module indicates that the DefaultAzureCredential class supports asynchronous operations. This means you can use it with asyncio to perform non-blocking authentication requests.

# %%
from azure.identity.aio import DefaultAzureCredential

# %% [markdown]
# # Explanation:
# from semantic_kernel.agents.azure_ai import AzureAIAgent, AzureAIAgentSettings: This imports the AzureAIAgent and AzureAIAgentSettings classes from the semantic_kernel.agents.azure_ai module. These classes are likely used to configure and interact with an AI agent provided by Azure.
#
# from semantic_kernel.contents.chat_message_content import ChatMessageContent: This imports the ChatMessageContent class from the semantic_kernel.contents.chat_message_content module. This class is likely used to handle the content of chat messages.
#
# from semantic_kernel.contents.utils.author_role import AuthorRole: This imports the AuthorRole class from the semantic_kernel.contents.utils.author_role module. This class is likely used to define the role of the author in a chat message (e.g., user, assistant).
#
# from semantic_kernel.functions.kernel_function_decorator import kernel_function: This imports the kernel_function decorator from the semantic_kernel.functions.kernel_function_decorator module. This decorator is likely used to mark functions as kernel functions, which can be used within the semantic kernel framework.
#
# # Purpose of the Imports:
# These imports set up the necessary components for working with an AI agent and handling chat messages within the semantic kernel framework. Here's a brief overview of each component:
#
# AzureAIAgent: This class is likely used to create and manage an AI agent that interacts with Azure AI services.
#
# AzureAIAgentSettings: This class is likely used to configure settings for the AzureAIAgent, such as authentication credentials and service endpoints.
#
# ChatMessageContent: This class is likely used to represent the content of chat messages, including text, metadata, and other relevant information.
#
# AuthorRole: This class is likely used to define the role of the author in a chat message, such as whether the message was sent by the user or the AI assistant.
#
# kernel_function: This decorator is likely used to mark functions as kernel functions, which can be used within the semantic kernel framework. Kernel functions are typically used to perform specific tasks or operations within the framework.

# %%
# %pip install --upgrade azure-ai-projects
# Out:
# Requirement already satisfied: azure-ai-projects in /usr/local/python/3.12.1/lib/python3.12/site-packages (1.0.0b7)
# Requirement already satisfied: isodate>=0.6.1 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from azure-ai-projects) (0.7.2)
# Requirement already satisfied: azure-core>=1.30.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from azure-ai-projects) (1.32.0)
# Requirement already satisfied: typing-extensions>=4.12.2 in /home/codespace/.local/lib/python3.12/site-packages (from azure-ai-projects) (4.12.2)
# Requirement already satisfied: requests>=2.21.0 in /home/codespace/.local/lib/python3.12/site-packages (from azure-core>=1.30.0->azure-ai-projects) (2.32.3)
# Requirement already satisfied: six>=1.11.0 in /home/codespace/.local/lib/python3.12/site-packages (from azure-core>=1.30.0->azure-ai-projects) (1.17.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/codespace/.local/lib/python3.12/site-packages (from requests>=2.21.0->azure-core>=1.30.0->azure-ai-projects) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /home/codespace/.local/lib/python3.12/site-packages (from requests>=2.21.0->azure-core>=1.30.0->azure-ai-projects) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/codespace/.local/lib/python3.12/site-packages (from requests>=2.21.0->azure-core>=1.30.0->azure-ai-projects) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /home/codespace/.local/lib/python3.12/site-packages (from requests>=2.21.0->azure-core>=1.30.0->azure-ai-projects) (2024.8.30)
#
# [notice] A new release of pip is available: 24.3.1 -> 25.0.1
# [notice] To update, run: python -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
from semantic_kernel.agents.azure_ai.azure_ai_agent import AzureAIAgent
from semantic_kernel.agents.azure_ai.azure_ai_agent_settings import AzureAIAgentSettings
from semantic_kernel.contents.chat_message_content import ChatMessageContent
from semantic_kernel.contents.utils.author_role import AuthorRole
from semantic_kernel.functions.kernel_function_decorator import kernel_function
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[36], line 1
# ----> 1 from semantic_kernel.agents.azure_ai.azure_ai_agent import AzureAIAgent
#       2 from semantic_kernel.agents.azure_ai.azure_ai_agent_settings import AzureAIAgentSettings
#       3 from semantic_kernel.contents.chat_message_content import ChatMessageContent
#
# File /usr/local/python/3.12.1/lib/python3.12/site-packages/semantic_kernel/agents/azure_ai/__init__.py:3
#       1 # Copyright (c) Microsoft. All rights reserved.
# ----> 3 from semantic_kernel.agents.azure_ai.azure_ai_agent import AzureAIAgent
#       4 from semantic_kernel.agents.azure_ai.azure_ai_agent_settings import AzureAIAgentSettings
#       6 __all__ = ["AzureAIAgent", "AzureAIAgentSettings"]
#
# File /usr/local/python/3.12.1/lib/python3.12/site-packages/semantic_kernel/agents/azure_ai/azure_ai_agent.py:27
#      24 from pydantic import Field
#      26 from semantic_kernel.agents.agent import Agent
# ---> 27 from semantic_kernel.agents.azure_ai.agent_thread_actions import AgentThreadActions
#      28 from semantic_kernel.agents.azure_ai.azure_ai_agent_settings import AzureAIAgentSettings
#      29 from semantic_kernel.agents.azure_ai.azure_ai_channel import AzureAIChannel
#
# File /usr/local/python/3.12.1/lib/python3.12/site-packages/semantic_kernel/agents/azure_ai/agent_thread_actions.py:33
#       8 from azure.ai.projects.models import (
#       9     AgentsApiResponseFormat,
#      10     AgentsApiResponseFormatMode,
#    (...)
#      29     TruncationObject,
#      30 )
#      31 from azure.ai.projects.models._enums import MessageRole
# ---> 33 from semantic_kernel.agents.azure_ai.agent_content_generation import (
#      34     generate_code_interpreter_content,
#      35     generate_function_call_content,
#      36     generate_function_call_streaming_content,
#      37     generate_function_result_content,
#      38     generate_message_content,
#      39     generate_streaming_code_interpreter_content,
#      40     generate_streaming_function_content,
#      41     generate_streaming_message_content,
#      42     get_function_call_contents,
#      43 )
#      44 from semantic_kernel.agents.azure_ai.azure_ai_agent_utils import AzureAIAgentUtils
#      45 from semantic_kernel.agents.open_ai.function_action_result import FunctionActionResult
#
# File /usr/local/python/3.12.1/lib/python3.12/site-packages/semantic_kernel/agents/azure_ai/agent_content_generation.py:5
#       1 # Copyright (c) Microsoft. All rights reserved.
#       3 from typing import TYPE_CHECKING, Any, cast
# ----> 5 from azure.ai.projects.models import (
#       6     MessageDeltaImageFileContent,
#       7     MessageDeltaImageFileContentObject,
#       8     MessageDeltaTextContent,
#       9     MessageDeltaTextFileCitationAnnotation,
#      10     MessageDeltaTextFilePathAnnotation,
#      11     MessageDeltaTextUrlCitationAnnotation,
#      12     MessageImageFileContent,
#      13     MessageTextContent,
#      14     MessageTextFileCitationAnnotation,
#      15     MessageTextFilePathAnnotation,
#      16     MessageTextUrlCitationAnnotation,
#      17     RunStep,
#      18     RunStepDeltaCodeInterpreterDetailItemObject,
#      19     RunStepDeltaCodeInterpreterImageOutput,
#      20     RunStepDeltaCodeInterpreterLogOutput,
#      21     RunStepDeltaCodeInterpreterToolCall,
#      22     RunStepDeltaFileSearchToolCall,
#      23     RunStepDeltaFunctionToolCall,
#      24     RunStepFunctionToolCall,
#      25     ThreadMessage,
#      26     ThreadRun,
#      27 )
#      29 from semantic_kernel.contents.annotation_content import AnnotationContent
#      30 from semantic_kernel.contents.chat_message_content import ChatMessageContent
#
# ImportError: cannot import name 'MessageDeltaTextUrlCitationAnnotation' from 'azure.ai.projects.models' (/usr/local/python/3.12.1/lib/python3.12/site-packages/azure/ai/projects/models/__init__.py)

# %%
from semantic_kernel.agents.azure_ai import AzureAIAgent, AzureAIAgentSettings
print(dir(AzureAIAgent))
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[39], line 1
# ----> 1 from semantic_kernel.agents.azure_ai import AzureAIAgent, AzureAIAgentSettings
#       2 print(dir(AzureAIAgent))
#
# File /usr/local/python/3.12.1/lib/python3.12/site-packages/semantic_kernel/agents/azure_ai/__init__.py:3
#       1 # Copyright (c) Microsoft. All rights reserved.
# ----> 3 from semantic_kernel.agents.azure_ai.azure_ai_agent import AzureAIAgent
#       4 from semantic_kernel.agents.azure_ai.azure_ai_agent_settings import AzureAIAgentSettings
#       6 __all__ = ["AzureAIAgent", "AzureAIAgentSettings"]
#
# File /usr/local/python/3.12.1/lib/python3.12/site-packages/semantic_kernel/agents/azure_ai/azure_ai_agent.py:27
#      24 from pydantic import Field
#      26 from semantic_kernel.agents.agent import Agent
# ---> 27 from semantic_kernel.agents.azure_ai.agent_thread_actions import AgentThreadActions
#      28 from semantic_kernel.agents.azure_ai.azure_ai_agent_settings import AzureAIAgentSettings
#      29 from semantic_kernel.agents.azure_ai.azure_ai_channel import AzureAIChannel
#
# File /usr/local/python/3.12.1/lib/python3.12/site-packages/semantic_kernel/agents/azure_ai/agent_thread_actions.py:33
#       8 from azure.ai.projects.models import (
#       9     AgentsApiResponseFormat,
#      10     AgentsApiResponseFormatMode,
#    (...)
#      29     TruncationObject,
#      30 )
#      31 from azure.ai.projects.models._enums import MessageRole
# ---> 33 from semantic_kernel.agents.azure_ai.agent_content_generation import (
#      34     generate_code_interpreter_content,
#      35     generate_function_call_content,
#      36     generate_function_call_streaming_content,
#      37     generate_function_result_content,
#      38     generate_message_content,
#      39     generate_streaming_code_interpreter_content,
#      40     generate_streaming_function_content,
#      41     generate_streaming_message_content,
#      42     get_function_call_contents,
#      43 )
#      44 from semantic_kernel.agents.azure_ai.azure_ai_agent_utils import AzureAIAgentUtils
#      45 from semantic_kernel.agents.open_ai.function_action_result import FunctionActionResult
#
# File /usr/local/python/3.12.1/lib/python3.12/site-packages/semantic_kernel/agents/azure_ai/agent_content_generation.py:5
#       1 # Copyright (c) Microsoft. All rights reserved.
#       3 from typing import TYPE_CHECKING, Any, cast
# ----> 5 from azure.ai.projects.models import (
#       6     MessageDeltaImageFileContent,
#       7     MessageDeltaImageFileContentObject,
#       8     MessageDeltaTextContent,
#       9     MessageDeltaTextFileCitationAnnotation,
#      10     MessageDeltaTextFilePathAnnotation,
#      11     MessageDeltaTextUrlCitationAnnotation,
#      12     MessageImageFileContent,
#      13     MessageTextContent,
#      14     MessageTextFileCitationAnnotation,
#      15     MessageTextFilePathAnnotation,
#      16     MessageTextUrlCitationAnnotation,
#      17     RunStep,
#      18     RunStepDeltaCodeInterpreterDetailItemObject,
#      19     RunStepDeltaCodeInterpreterImageOutput,
#      20     RunStepDeltaCodeInterpreterLogOutput,
#      21     RunStepDeltaCodeInterpreterToolCall,
#      22     RunStepDeltaFileSearchToolCall,
#      23     RunStepDeltaFunctionToolCall,
#      24     RunStepFunctionToolCall,
#      25     ThreadMessage,
#      26     ThreadRun,
#      27 )
#      29 from semantic_kernel.contents.annotation_content import AnnotationContent
#      30 from semantic_kernel.contents.chat_message_content import ChatMessageContent
#
# ImportError: cannot import name 'MessageDeltaTextUrlCitationAnnotation' from 'azure.ai.projects.models' (/usr/local/python/3.12.1/lib/python3.12/site-packages/azure/ai/projects/models/__init__.py)

# %% [markdown]
# # Explanation:
#
# This is a class imported from the semantic_kernel.agents.azure_ai module. It is used to configure settings for an AI agent that interacts with Azure AI services.
#
# create() Method: The create() method is a class method of AzureAIAgentSettings. It is used to create and initialize an instance of AzureAIAgentSettings with default or predefined settings.
#
# ai_agent_settings Variable: The variable ai_agent_settings is assigned the instance of AzureAIAgentSettings created by the create() method. This instance contains the configuration settings needed to set up and use an Azure AI agent.
#
# # Purpose:
# The purpose of this line is to create a configuration object (ai_agent_settings) that holds the necessary settings for an Azure AI agent. These settings might include authentication credentials, service endpoints, and other configuration parameters required to interact with Azure AI services.

# %%
ai_agent_settings = AzureAIAgentSettings.create()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 ai_agent_settings = AzureAIAgentSettings.create()
#
# NameError: name 'AzureAIAgentSettings' is not defined

# %% [markdown]
# # Explanation:
# import requests: This statement imports the requests library, which is a popular third-party library in Python used for making HTTP requests.
#
# Purpose: The requests library simplifies the process of sending HTTP requests and handling responses. It provides a user-friendly interface for interacting with web services and APIs.
#
# Common Use Cases: Sending HTTP Requests: You can use the requests library to send various types of HTTP requests, such as GET, POST, PUT, DELETE, etc.
#
# Handling Responses:The library makes it easy to handle responses, including reading response content, headers, status codes, and more.
# Working with APIs:
#
# The requests library is commonly used to interact with RESTful APIs, allowing you to send data to and retrieve data from web services.

# %%
import requests

# %% [markdown]
# # Explanation:
# This is a variable that stores the API key for accessing a SERP (Search Engine Results Page) API service. An API key is a unique identifier used to authenticate requests associated with your account.
#
# Purpose: The purpose of this line is to store the API key in a variable so that it can be used to authenticate requests to the SERP API service. The API key is required to access the service and perform searches.
# How to Get a SERP API Key: To get a SERP API key, follow these general steps at https://serpapi.com (the exact steps may vary depending on the specific SERP API service you are using):
#
# Choose a SERP API Service: There are several SERP API services available, such as SerpAPI, Google Custom Search JSON API, and others. Choose the one that best fits your needs.
#
# Sign Up for an Account: Go to the website of the chosen SERP API service and sign up for an account. You may need to provide some basic information and verify your email address.
#
# Create an API Key: After signing up, log in to your account and navigate to the API section or dashboard. Look for an option to create or generate a new API key.
# Copy the API Key to your .env file.

# %%
SERP_API_KEY='SERPAPI_SEARCH_API_KEY'

# %% [markdown]
# # Explanation:
# BASE_URL: This is a variable that stores the base URL for the SERP API endpoint. The variable name BASE_URL is a convention used to indicate that this URL is the starting point for making API requests.
# 'https://serpapi.com/search':
#
# This is the actual URL string assigned to the BASE_URL variable. It represents the endpoint for performing search queries using the SERP API.
#
# # Purpose:
# The purpose of this line is to define a constant that holds the base URL for the SERP API. This URL will be used as the starting point for constructing API requests to perform search operations.
#
# # Usage:
# By defining the base URL in a variable, you can easily reuse it throughout your code whenever you need to make requests to the SERP API. This makes your code more maintainable and reduces the risk of errors from hardcoding the URL in multiple places. The current example is https://serpapi.com/search?engine=bing which is using Bing search API. Different API can be selected at https://Serpapi.com

# %%
BASE_URL = 'https://serpapi.com/search?engine=bing'

# %% [markdown]
# # Explanation:
#
# This is where you agent code is located.
#
# Class Definition: class BookingPlugin:: Defines a class named BookingPlugin that contains methods for booking hotels and flights.
# Docstring: """Booking Plugin for customers""": A docstring that describes the purpose of the BookingPlugin class.
# Hotel Booking Method:
#
# @kernel_function(description="booking hotel"): A decorator that describes the function as a kernel function for booking hotels.
# def booking_hotel(self, query: Annotated[str, "The name of the city"], check_in_date: Annotated[str, "Hotel Check-in Time"], check_out_date: Annotated[str, "Hotel Check-out Time"]) -> Annotated[str, "Return the result of booking hotel information"]:: Defines a method for booking hotels with annotated parameters and return type.
#
# The method constructs a dictionary of parameters for the hotel booking request and sends a GET request to the SERP API. It checks the response status and returns the hotel properties if successful, or None if the request failed.
#
# Flight Booking Method: @kernel_function(description="booking flight"): A decorator that describes the function as a kernel function for booking flights.
# def booking_flight(self, origin: Annotated[str, "The name of Departure"], destination: Annotated[str, "The name of Destination"], outbound_date: Annotated[str, "The date of outbound"], return_date: Annotated[str, "The date of Return_date"]) -> Annotated[str, "Return the result of booking flight information"]:: Defines a method for booking flights with annotated parameters and return type.
#
# The method constructs dictionaries of parameters for the outbound and return flight requests and sends GET requests to the SERP API. It checks the response status and appends the flight information to the result string if successful, or prints an error message if the request failed. The method returns the result string containing the flight information.

# %%
# Define Booking Plugin
class BookingPlugin:
    """Booking Plugin for customers"""

    @kernel_function(description="booking hotel")
    def booking_hotel(self, query: Annotated[str, "The name of the city"], check_in_date: Annotated[str, "Hotel Check-in Time"], check_out_date: Annotated[str, "Hotel Check-out Time"]) -> Annotated[str, "Return the result of booking hotel information"]:
        """
        Function to book a hotel.
        Parameters:
        - query: The name of the city
        - check_in_date: Hotel Check-in Time
        - check_out_date: Hotel Check-out Time
        Returns:
        - The result of booking hotel information
        """

        # Define the parameters for the hotel booking request
        params = {
            "engine": "google_hotels",
            "q": query,
            "check_in_date": check_in_date,
            "check_out_date": check_out_date,
            "adults": "1",
            "currency": "GBP",
            "gl": "uk",
            "hl": "en",
            "api_key": SERP_API_KEY
        }

        # Send the GET request to the SERP API
        response = requests.get(BASE_URL, params=params)

        # Check if the request was successful
        if response.status_code == 200:
            # Parse the response content as JSON
            response = response.json()
            # Return the properties from the response
            return response["properties"]
        else:
            # Return None if the request failed
            return None

    @kernel_function(description="booking flight")
    def booking_flight(self, origin: Annotated[str, "The name of Departure"], destination: Annotated[str, "The name of Destination"], outbound_date: Annotated[str, "The date of outbound"], return_date: Annotated[str, "The date of Return_date"]) -> Annotated[str, "Return the result of booking flight information"]:
        """
        Function to book a flight.
        Parameters:
        - origin: The name of Departure
        - destination: The name of Destination
        - outbound_date: The date of outbound
        - return_date: The date of Return_date
        - airline: The preferred airline carrier
        - hotel_brand: The preferred hotel brand
        Returns:
        - The result of booking flight information
        """
        
        # Define the parameters for the outbound flight request
        go_params = {
            "engine": "google_flights",
            "departure_id": "destination",
            "arrival_id": "origin",
            "outbound_date": "outbound_date",
            "return_date": "return_date",
            "currency": "GBP",
            "hl": "en",
            "airline": "airline",
            "hotel_brand": "hotel_brand",
            "api_key": "SERP_API_KEY"
        }
 
 
 
        print(go_params)

        # Send the GET request for the outbound flight
        go_response = requests.get(BASE_URL, params=go_params)

        # Initialize the result string
        result = ''

        # Check if the outbound flight request was successful
        if go_response.status_code == 200:
            # Parse the response content as JSON
            response = go_response.json()
            # Append the outbound flight information to the result
            result += "# outbound \n " + str(response)
        else:
            # Print an error message if the request failed
            print('error!!!')

        # Define the parameters for the return flight request
        back_params = {
            #"engine": "google_flights",
            "departure_id": destination,
            "arrival_id": origin,
            "outbound_date": outbound_date,
            "return_date": return_date,
            "currency": "GBP",
            "hl": "en",
            "api_key": SERP_API_KEY
        }

        # Send the GET request for the return flight
        back_response = requests.get(BASE_URL, params=back_params)

        # Check if the return flight request was successful
        if back_response.status_code == 200:
            # Parse the response content as JSON
            response = back_response.json()
            # Append the return flight information to the result
            result += "\n # return \n" + str(response)
        else:
            # Print an error message if the request failed
            print('error!!!')

        # Print the result
        print(result)

        # Return the result
        return result

# %% [markdown]
# # Explanation:
# Import Statements: Import necessary modules for Azure credentials, AI agent, chat message content, author role, and kernel function decorator.
#
# Asynchronous Context Manager: async with (DefaultAzureCredential() as creds, AzureAIAgent.create_client(credential=creds, conn_str="...") as client,):: This sets up an asynchronous context manager to handle Azure credentials and create an AI agent client.
#
# Agent Name and Instructions: AGENT_NAME = "BookingAgent": Defines the name of the agent.
# AGENT_INSTRUCTIONS = """...""": Provides detailed instructions for the agent on how to handle booking requests.
#
# Create Agent Definition: agent_definition = await client.agents.create_agent(...): Creates an agent definition with the specified model, name, and instructions.
#
# Create AzureAI Agent: agent = AzureAIAgent(...): Creates an AzureAI agent using the client and agent definition.
#
# Add Booking Plugin: agent.kernel.add_plugin(BookingPlugin(), plugin_name="booking"): Adds the BookingPlugin to the agent's kernel.
#
# Create Thread: thread = await client.agents.create_thread(): Creates a new thread for the agent.
#
# User Inputs: user_inputs = ["..."]: Defines a list of user inputs for the agent to process.
#
# Process User Inputs:For each user input, add it as a chat message, invoke the agent, and print the agent's response.
# Clean Up:
#
# In the finally block, delete the thread and agent to clean up resources.

# %%
# Import necessary modules
from azure.identity.aio import DefaultAzureCredential
from semantic_kernel.agents.azure_ai import AzureAIAgent, AzureAIAgentSettings
from semantic_kernel.contents.chat_message_content import ChatMessageContent
from semantic_kernel.contents.utils.author_role import AuthorRole
from semantic_kernel.functions.kernel_function_decorator import kernel_function

# Azure AI Setting
async with (
     DefaultAzureCredential() as creds,
            AzureAIAgent.create_client(
                credential=creds,
                conn_str=ai_agent_settings.project_connection_string.get_secret_value(),
            ) as client,
):    
    
    # Define the agent's name and instructions
    AGENT_NAME = "BookingAgent"
    AGENT_INSTRUCTIONS = """
    You are a booking agent, help me to book flights or hotels.

    Thought: Understand the user's intention and confirm whether to use the reservation system to complete the task.

    Action:
    - If booking a flight, convert the departure name and destination name into airport codes.
    - If booking a hotel or flight, use the corresponding API to call. Ensure that the necessary parameters are available. If any parameters are missing, use default values or assumptions to proceed.
    - If it is not a hotel or flight booking, respond with the final answer only.
    - Output the results using a markdown table:
    - For flight bookings, separate the outbound and return contents and list them in the order of Departure_airport Name | Airline | Flight Number | Departure Time | Arrival_airport Name | Arrival Time | Duration | Airplane | Travel Class | Price (USD) | Legroom | Extensions | Carbon Emissions (kg).
    - For hotel bookings, list them in the order of Properties Name | Properties description | check_in_time | check_out_time | prices | nearby_places | hotel_class | gps_coordinates.
"""

    # Create agent definition with the specified model, name, and instructions
    agent_definition = await client.agents.create_agent(
        model=ai_agent_settings.model_deployment_name,
        name=AGENT_NAME,
        instructions=AGENT_INSTRUCTIONS,
    )

    # Create the AzureAI Agent using the client and agent definition
    agent = AzureAIAgent(
        client=client,
        definition=agent_definition,
        # Optionally configure polling options
        # polling_options=RunPollingOptions(run_polling_interval=timedelta(seconds=1)),
    )

    # Add the BookingPlugin to the agent's kernel
    agent.kernel.add_plugin(BookingPlugin(), plugin_name="booking")

    # Create a new thread for the agent
    thread = await client.agents.create_thread()

    # This is your prompt for the activity or task you want to complete 
    # Define user inputs for the agent to process we have provided some example prompts to test and validate 
    user_inputs = [
        # "Can you tell me the round-trip air ticket from  London to New York JFK aiport, the departure time is February 17, 2025, and the return time is February 23, 2025"
        # "Book a hotel in New York from Feb 20,2025 to Feb 24,2025"
        "Help me book flight tickets and hotel for the following trip London Heathrow LHR Feb 20th 2025 to New York JFK returning Feb 27th 2025 flying economy with British Airways only. I want a stay in a Hilton hotel in New York please provide costs for the flight and hotel"
        # "I have a business trip from London LHR to New York JFK on Feb 20th 2025 to Feb 27th 2025, can you help me to book a hotel and flight tickets"
    ]

    try:
        # Process each user input
        for user_input in user_inputs:
            # Add the user input as a chat message
            await agent.add_chat_message(
                thread_id=thread.id, message=ChatMessageContent(role=AuthorRole.USER, content=user_input)
            )
            print(f"# User: '{user_input}'")
            # Invoke the agent for the specified thread
            async for content in agent.invoke(
                thread_id=thread.id,
                temperature=0.2,  # Override the agent-level temperature setting with a run-time value
            ):
                if content.role != AuthorRole.TOOL:
                    print(f"# Agent: {content.content}")
    finally:
        # Clean up by deleting the thread and agent
        await client.agents.delete_thread(thread.id)
        await client.agents.delete_agent(agent.id)
